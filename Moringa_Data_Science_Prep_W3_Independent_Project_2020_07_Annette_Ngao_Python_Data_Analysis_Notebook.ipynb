# %% [markdown]
# # MTN Data analysis

# %% [markdown]
# importing libraries

# %%
import time
import numpy as np
import pandas as pd

# %% [markdown]
# Loading cells_geo.csv file

# %%
data_file_1 = pd.read_csv('cells_geo.csv', delimiter = ';')
data_file_1
# Out:
#       Unnamed: 0    VILLES      STATUS LOCALISATION    DECOUPZONE  \
# 0              0    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 1              1    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 2              2    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 3              3   ASSINIE  In Service    INTERIEUR     Grand-EST
# 4              4   ASSINIE  In Service    INTERIEUR     Grand-EST
# ...          ...       ...         ...          ...           ...
# 3969        3969  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3970        3970  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3971        3971  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3972        3972  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3973        3973  ZUENOULA  In Service    INTERIEUR    Grand-NORD
#
#                  ZONENAME  LONGITUDE  LATITUDE     REGION          AREA  \
# 0                AGBANNEW  -4.000667  5.368194     LAGUNE           NaN
# ...

# %% [markdown]
# Loading Telcom_dataset file

# %%
data_file_2 = pd.read_csv('Telcom_dataset.csv')
data_file_2
# Out:
#      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %% [markdown]
# Loading Telcom_dataset2

# %%
data_file_3 = pd.read_csv('Telcom_dataset2.csv')
data_file_3
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %% [markdown]
# Loading Telcom_dataset3

# %%
data_file_4 = pd.read_csv('Telcom_dataset3.csv')
data_file_4
# Out:
#      PRODUCT  VALUE DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  DW_B_NUMBER_INT  \
# 0      Voice     61   01:28.0            2  966f68353622feb  ffd53a3bb2db6f1
# 1        sms      0   01:31.0            1  a0a597384c612d7  cf3b218f1dde792
# 2      Voice     10   02:59.0            1  5441a9a58c97132  52f8b299515b9b7
# 3        sms      0   03:04.0            0  8ab8b9ed6989f61  e09e736e46c5c3d
# 4      Voice     22   03:16.0            4  52662a62b199334  2186273faab4602
# ...      ...    ...       ...          ...              ...              ...
# 4996   Voice      0   01:43.0            3  467333ade2b4b9c  0ab2acd804d01fe
# 4997   Voice     62   01:43.0            1  e077a6b74c5053c  4c8098eb6ea1a41
# 4998   Voice     32   01:43.0            1  77f53c39d27c050  9d064f013e2cab2
# 4999   Voice     30   01:43.0            2  672ce74c418aa7a  f9ff5af59cf0d68
# 5000   Voice     60   01:43.0            2  6edeb4c55714650  7e60838216482a7
#
# ...

# %% [markdown]
# Finding the most used city in Telcom_dataset
# The site ID that appears most will be obtained using the mode function
# Then the site ID will be obtained from the cel_geo data set to find the most used city

# %%
mode_day_1 = data_file_2.SITE_ID.mode()
print(mode_day_1)
# Out:
# 0    b47a998a3e
# dtype: object

# %%
data_file_1.loc[data_file_1["SITE_CODE"]== "b47a998a3e", "VILLES" ].iloc[0]
# Out:
# 'YOPOUGON'

# %% [markdown]
# Finding the most used city in Telcom_dataset2 The site ID that appears most will be obtained using the mode function
# Then the site ID will be obtained from the cel_geo data set to find the most used city

# %%
mode_day_2 = data_file_3.SITE_ID.mode()
print(mode_day_2)
# Out:
# 0    91e86be9a6
# dtype: object

# %% [markdown]
# Finding the specific city with the site Id appearing most in the data
#
#
# Again YOPOUGON is the most used city but with another identifiable SITE_CODE

# %%
data_file_1.loc[data_file_1["SITE_CODE"]== "91e86be9a6", "VILLES" ].iloc[0]
# Out:
# 'YOPOUGON'

# %% [markdown]
# Finding the most used city in Telcom_dataset3 The site ID that appears most will be obtained using the mode function Then the site ID will be obtained from the cel_geo data set to find the most used city

# %%
mode_day_3 = data_file_4.SITE_ID.mode()
print(mode_day_3)
# Out:
# 0    1ddea341cd
# dtype: object

# %%
#Finding the specific city with the site Id appearing most in the data
#Again YOPOUGON is the most used city but with another identifiable SITE_CODE
#data_file_1[data_file_1.SITE_CODE =="1ddea341cd"].head(1)
data_file_1.loc[data_file_1["SITE_CODE"]== "1ddea341cd", "VILLES" ].iloc[0]
# Out:
# 'SAN-PEDRO'

# %% [markdown]
# Most used cities during business hours for the first day

# %%
from time import mktime
from datetime import datetime

def getTimeCat(Datetime):
    # extract time categories
    str_time = datetime.strptime(Datetime, "%m/%j/%y %H:%M:MS")
    ts = datetime.fromtimestamp(mktime(str_time))

    # --> Business hours = 0800-1700
    businessStart = datetime.time(8, 0, 1)
    businessEnd = datetime.time(17, 0, 0)

    # --> home hours = 1700-0800
    midStart = datetime.time(17, 0, 1)
    midEnd = datetime.time(8, 0, 0)

    if time_in_range(businessStart, businessEnd, ts):
      timecat = 0 #business hours
    elif time_in_range(homeStart, homeEnd, ts):
      timecat = 1 #home hours

# %% [markdown]
# Finding the most used product for the first day(TelcomDataset.csv)

# %%
mode_prod_1 = data_file_2.PRODUTC.mode()
print(mode_prod_1)
# Out:
# 0    Voice
# dtype: object

# %% [markdown]
# Finding the most used product for the second day(TelcomDataset2.csv)

# %%
mode_prod_2 = data_file_3.PRODUCT.mode()
print(mode_prod_2)
# Out:
# 0    sms
# dtype: object

# %% [markdown]
# Finding the most used product for the second day(TelcomDataset3.csv)

# %%
mode_prod_3 = data_file_4.PRODUCT.mode()
print(mode_prod_3)
# Out:
# 0    sms
# dtype: object

# %% [raw]
# Merging the three datasets containing the information concerning the usage of products by consumers

# %%
data = pd.concat([data_file_2, data_file_3,data_file_4], axis=0)
#data = data_file_2.append(data_file_3).append(data_file_4) which gave the output
data
# Out:
#      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     NaN      0                    NaN            3  467333ade2b4b9c
# 4997     NaN     62                    NaN            1  e077a6b74c5053c
# 4998     NaN     32                    NaN            1  77f53c39d27c050
# 4999     NaN     30                    NaN            2  672ce74c418aa7a
# 5000     NaN     60                    NaN            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID PRODUCT  \
# ...

# %% [markdown]
# The most used product for the three days

# %%
mode_prod_data = data.PRODUTC.mode()
print(mode_prod_data)
# Out:
# 0    Voice
# dtype: object

# %% [markdown]
# Overall city that was most used

# %%
mode_city_all = data.SITE_ID.mode()
print(mode_city_all)
# Out:
# 0    7f76d66503
# dtype: object

# %% [markdown]
# Finding the name of the city with the SITE_COD obtained above

# %%
data_file_1.loc[data_file_1["SITE_CODE"]== "7f76d66503", "VILLES" ].iloc[0]
# Out:
# 'ATTECOUBE'
